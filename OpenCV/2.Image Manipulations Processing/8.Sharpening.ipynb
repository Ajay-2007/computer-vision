# %% [markdown]
# ## Sharpening
# By altering our kernels we can implement sharpening, which has the effects of in strengthening or emphasizing edges in an image.

# %%
import cv2
import numpy as np
from IPython.display import display, HTML
import cv2
import base64
import matplotlib.pyplot as plt
# %matplotlib inline 


def imshow(name, imageArray):
    # print(name)
    _, png = cv2.imencode('.png', imageArray)
    encoded = base64.b64encode(png)
    return HTML(
        data='''<p>{2}</p><img alt="{0}" src="...{1}"/>'''.format(name, encoded.decode('ascii'),
                                                                                      name))

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from pathlib import Path
import os
path = Path.cwd() / 'drive' / 'My Drive' / 'Github' / 'computer vision' / 'OpenCV' / 'images'
path = os.path.join(path, 'input.jpg')
image = cv2.imread(path)
# print(path)
# image = np.array(path)

# %%
print(image.shape)
# Out:
# (415, 622, 3)

# %%
imshow('Original Image', image)
# Out:
# <p>Original Image</p><img alt="Original Image" src="......"/>

# %%
# Create our sharpneing kernel, we don't normalize since the value 
# in the matrix sum to 1

kernel_sharpening = np.array([[-1,-1,-1],
                              [-1, 9,-1],
                              [-1,-1,-1]])

# apply different kernels to the input image

sharpened = cv2.filter2D(image, -1, kernel_sharpening)
imshow("Image Sharpening", sharpened)
# Out:
# <p>Image Sharpening</p><img alt="Image Sharpening" src="......"/>
