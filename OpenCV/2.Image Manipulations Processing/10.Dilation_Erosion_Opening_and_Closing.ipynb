# %% [markdown]
# ## Dilation, Erosion, Opening and Closing
#
# These are operations in the field of mathematical morphology:
# - `Dilation` - Adds pixels to the boundaries of objects in an image
# - `Erosion` - Removes pixels at the bounaries of objects in an image
# - `Opening` - Erosion followed by dilation
# - `Closing` - Dilation followed by erosion

# %%
from google.colab import drive
drive.mount('/content/drive')

import cv2
import numpy as np
from IPython.display import display, HTML
import base64
import os

def imshow(name, imageArray):
    # print(name)
    _, png = cv2.imencode('.png', imageArray)
    encoded = base64.b64encode(png)
    return HTML(
        data='''<p>{2}</p><img alt="{0}" src="...{1}"/>'''.format(name, encoded.decode('ascii'),
                                                                                      name))

from pathlib import Path
import os
path = Path.cwd() / 'drive' / 'My Drive' / 'Github' / 'computer vision' / 'OpenCV' / 'images'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_path = os.path.join(path, 'opencv_inv.png')

# opening image in grayscale
image = cv2.imread(image_path, 0)
imshow('Origianl Image', image)
# Out:
# <p>Origianl Image</p><img alt="Origianl Image" src="......"/>

# %%
# Let's define our kernel size
kernel = np.ones((5, 5), np.uint8)

# %%
# Now we erode
erosion = cv2.erode(image, kernel, iterations = 1)
imshow('Erosion', erosion)
# Out:
# <p>Erosion</p><img alt="Erosion" src="......"/>

# %%
# Now we dilation
dilation = cv2.dilate(image, kernel, iterations = 1)
imshow('Dilation', dilation)
# Out:
# <p>Dilation</p><img alt="Dilation" src="......"/>

# %%
# Opening - Good for removing noise
opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
imshow('Opening', opening)
# Out:
# <p>Opening</p><img alt="Opening" src="......"/>

# %%
# Closing - Good for removing noise
closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
imshow('Closing', closing)
# Out:
# <p>Closing</p><img alt="Closing" src="......"/>
